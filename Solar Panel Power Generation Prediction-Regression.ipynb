# %%
#import libraries
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import figure
import pickle

from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
#Read Data
data = pd.read_csv('D:\Bit Code\Solar Panel\data.csv')
data
# Out:
#            state_name  region_name  percent_qualified  yearly_sunlight_kwh_f  \
# 0          California   6037104401          86.303387           2.539152e+06
# 1            New York  36055009400          85.813953           2.815855e+07
# 2            Illinois  17201000700          56.446991           2.850205e+06
# 3        Pennsylvania  42003180300          38.297872           1.432569e+06
# 4          California   6059086602          90.382514           1.183461e+07
# ...               ...          ...                ...                    ...
# 48717           Texas  48121020113          84.426947           4.693639e+05
# 48718      New Jersey  34027042302          45.887850           1.764473e+07
# 48719      California   6037543322          96.548550           1.538690e+07
# 48720  South Carolina  45079010309          83.550045           3.117499e+06
# 48721        New York  36079011300         100.000000           0.000000e+00
#
#        yearly_sunlight_kwh_e  yearly_sunlight_kwh_n  yearly_sunlight_kwh_s  \
# 0               1.014756e+06           1.075291e+06           1.760043e+06
# 1               7.338827e+05           1.739810e+05           1.342966e+06
# 2               1.024630e+06           1.342642e+05           3.155397e+06
# 3               1.203715e+06           7.318190e+04           7.604248e+05
# 4               2.070519e+06           1.691435e+06           3.551939e+06
# ...                      ...                    ...                    ...
# 48717           4.147494e+06           4.619307e+05           1.036969e+07
# 48718           1.208407e+06           4.270519e+04           1.835456e+06
# 48719           3.611829e+06           1.928394e+06           6.935740e+06
# 48720           7.984434e+06           1.216144e+06           1.185587e+07
# 48721           1.099506e+03           0.000000e+00           2.248673e+04
#
#        yearly_sunlight_kwh_w  yearly_sunlight_kwh_total  number_of_panels_e  \
# 0               1.533140e+06               7.922383e+06                2964
# 1               7.666855e+05               3.117606e+07                2760
# 2               1.173068e+06               8.337565e+06                3841
# 3               4.425539e+05               3.912445e+06                4920
# 4               3.269615e+06               2.241812e+07                5933
# ...                      ...                        ...                 ...
# 48717           6.523585e+06               2.197206e+07               13393
# 48718           7.341181e+05               2.146542e+07                4499
# 48719           4.787012e+06               3.264987e+07               10146
# 48720           9.036818e+06               3.321077e+07               26425
# 48721           6.683992e+03               3.027023e+04                   4
#
#        number_of_panels_f  number_of_panels_n  number_of_panels_s  \
# 0                    6574                3159                4352
# 1                  102635                 693                4578
# 2                    9963                 535               10649
# 3                    5001                 299                2529
# 4                   31555                5146                8933
# ...                   ...                 ...                 ...
# 48717                1375                1587               28278
# 48718               60447                 168                6455
# 48719               40522                5723               17096
# 48720                9416                4200               35235
# 48721                   0                   0                  73
#
#        number_of_panels_w  number_of_panels_total    lat_avg     lng_avg  \
# 0                    3827                 20876.0  34.267040 -118.432716
# 1                    2899                113565.0  43.156368  -77.607040
# 2                    4421                 29409.0  42.277794  -89.066589
# 3                    1644                 14393.0  40.422962  -79.993729
# 4                    8827                 60394.0  33.844044 -117.933113
# ...                   ...                     ...        ...         ...
# 48717               19889                 64522.0  33.176277  -96.911400
# 48718                2804                 74373.0  40.838047  -74.476219
# 48719               12666                 86153.0  33.852547 -118.256958
# 48720               28782                104058.0  34.113491  -81.140663
# 48721                  25                   102.0  41.360306  -73.730499
#
#        kw_total
# 0       5219.00
# 1      28391.25
# 2       7352.25
# 3       3598.25
# 4      15098.50
# ...         ...
# 48717  16130.50
# 48718  18593.25
# 48719  21538.25
# 48720  26014.50
# 48721     25.50
#
# [48722 rows x 18 columns]

# %%
#Shape of dataset
data.shape
# Out:
# (48722, 18)

# %%
#remove unwanted data
data=data.drop(labels=['yearly_sunlight_kwh_e', 'yearly_sunlight_kwh_n','yearly_sunlight_kwh_s','yearly_sunlight_kwh_w','number_of_panels_e','number_of_panels_s','number_of_panels_w','yearly_sunlight_kwh_f','number_of_panels_f','number_of_panels_n'], axis=1)
data
# Out:
#            state_name  region_name  percent_qualified  \
# 0          California   6037104401          86.303387
# 1            New York  36055009400          85.813953
# 2            Illinois  17201000700          56.446991
# 3        Pennsylvania  42003180300          38.297872
# 4          California   6059086602          90.382514
# ...               ...          ...                ...
# 48717           Texas  48121020113          84.426947
# 48718      New Jersey  34027042302          45.887850
# 48719      California   6037543322          96.548550
# 48720  South Carolina  45079010309          83.550045
# 48721        New York  36079011300         100.000000
#
#        yearly_sunlight_kwh_total  number_of_panels_total    lat_avg  \
# 0                   7.922383e+06                 20876.0  34.267040
# 1                   3.117606e+07                113565.0  43.156368
# 2                   8.337565e+06                 29409.0  42.277794
# 3                   3.912445e+06                 14393.0  40.422962
# 4                   2.241812e+07                 60394.0  33.844044
# ...                          ...                     ...        ...
# 48717               2.197206e+07                 64522.0  33.176277
# 48718               2.146542e+07                 74373.0  40.838047
# 48719               3.264987e+07                 86153.0  33.852547
# 48720               3.321077e+07                104058.0  34.113491
# 48721               3.027023e+04                   102.0  41.360306
#
#           lng_avg  kw_total
# 0     -118.432716   5219.00
# 1      -77.607040  28391.25
# 2      -89.066589   7352.25
# 3      -79.993729   3598.25
# 4     -117.933113  15098.50
# ...           ...       ...
# 48717  -96.911400  16130.50
# 48718  -74.476219  18593.25
# 48719 -118.256958  21538.25
# 48720  -81.140663  26014.50
# 48721  -73.730499     25.50
#
# [48722 rows x 8 columns]

# %%
#Type of datatypes
data.dtypes
# Out:
# state_name                    object
# region_name                    int64
# percent_qualified            float64
# yearly_sunlight_kwh_total    float64
# number_of_panels_total       float64
# lat_avg                      float64
# lng_avg                      float64
# kw_total                     float64
# dtype: object

# %%
#Check Null Values
data.isnull().sum()
# Out:
# state_name                    1
# region_name                   0
# percent_qualified             0
# yearly_sunlight_kwh_total    58
# number_of_panels_total       58
# lat_avg                       0
# lng_avg                       0
# kw_total                     58
# dtype: int64

# %%
# Summary of the data set
data.describe([0.05, 0.50, 0.95, 0.99]).T
# Out:
#                              count          mean           std           min  \
# region_name                48722.0  2.667656e+10  1.619133e+10  1.001020e+09
# percent_qualified          48722.0  7.741123e+01  1.571284e+01  0.000000e+00
# yearly_sunlight_kwh_total  48664.0  2.234360e+07  2.262537e+07  2.178341e+03
# number_of_panels_total     48664.0  6.848364e+04  6.652033e+04  8.000000e+00
# lat_avg                    48722.0  3.745727e+01  5.070044e+00  1.956049e+01
# lng_avg                    48722.0 -9.301239e+01  1.712806e+01 -1.581242e+02
# kw_total                   48664.0  1.712091e+04  1.663008e+04  2.000000e+00
#
#                                      5%           50%           95%  \
# region_name                6.001407e+09  2.616350e+10  5.174021e+10
# percent_qualified          4.861354e+01  7.980376e+01  9.757914e+01
# yearly_sunlight_kwh_total  2.180302e+06  1.686481e+07  5.972376e+07
# number_of_panels_total     7.370050e+03  5.292250e+04  1.797662e+05
# lat_avg                    2.853307e+01  3.844280e+01  4.487137e+01
# lng_avg                   -1.221821e+02 -8.768416e+01 -7.332281e+01
# kw_total                   1.842513e+03  1.323062e+04  4.494156e+04
#
#                                     99%           max
# region_name                5.507902e+10  5.603997e+10
# percent_qualified          9.944134e+01  1.000000e+02
# yearly_sunlight_kwh_total  1.039047e+08  5.339304e+08
# number_of_panels_total     3.102752e+05  1.545850e+06
# lat_avg                    4.765683e+01  6.498893e+01
# lng_avg                   -7.106571e+01 -6.826817e+01
# kw_total                   7.756880e+04  3.864625e+05

# %%
#Decription of dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48722 entries, 0 to 48721
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state_name                 48721 non-null  object
#  1   region_name                48722 non-null  int64
#  2   percent_qualified          48722 non-null  float64
#  3   yearly_sunlight_kwh_total  48664 non-null  float64
#  4   number_of_panels_total     48664 non-null  float64
#  5   lat_avg                    48722 non-null  float64
#  6   lng_avg                    48722 non-null  float64
#  7   kw_total                   48664 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 3.0+ MB

# %% [markdown]
# # Pre Process DataSet

# %%
#Dropped rows which contatinge null values
data=data.dropna()

# %%
#Check Null Values
data.isnull().sum()
# Out:
# state_name                   0
# region_name                  0
# percent_qualified            0
# yearly_sunlight_kwh_total    0
# number_of_panels_total       0
# lat_avg                      0
# lng_avg                      0
# kw_total                     0
# dtype: int64

# %%
# Summary of the preporcessed data set
data.describe([0.05, 0.50, 0.95, 0.99]).T
# Out:
#                              count          mean           std           min  \
# region_name                48664.0  2.667997e+10  1.618663e+10  1.001020e+09
# percent_qualified          48664.0  7.750349e+01  1.549313e+01  1.448226e-01
# yearly_sunlight_kwh_total  48664.0  2.234360e+07  2.262537e+07  2.178341e+03
# number_of_panels_total     48664.0  6.848364e+04  6.652033e+04  8.000000e+00
# lat_avg                    48664.0  3.745051e+01  5.052329e+00  1.956049e+01
# lng_avg                    48664.0 -9.299219e+01  1.709673e+01 -1.581242e+02
# kw_total                   48664.0  1.712091e+04  1.663008e+04  2.000000e+00
#
#                                      5%           50%           95%  \
# region_name                6.001408e+09  2.616351e+10  5.174087e+10
# percent_qualified          4.880065e+01  7.982665e+01  9.758246e+01
# yearly_sunlight_kwh_total  2.180302e+06  1.686481e+07  5.972376e+07
# number_of_panels_total     7.370050e+03  5.292250e+04  1.797662e+05
# lat_avg                    2.853309e+01  3.844180e+01  4.486323e+01
# lng_avg                   -1.221768e+02 -8.768378e+01 -7.332192e+01
# kw_total                   1.842513e+03  1.323062e+04  4.494156e+04
#
#                                     99%           max
# region_name                5.507902e+10  5.603997e+10
# percent_qualified          9.944134e+01  1.000000e+02
# yearly_sunlight_kwh_total  1.039047e+08  5.339304e+08
# number_of_panels_total     3.102752e+05  1.545850e+06
# lat_avg                    4.764774e+01  6.498893e+01
# lng_avg                   -7.106576e+01 -6.826817e+01
# kw_total                   7.756880e+04  3.864625e+05

# %% [markdown]
# # Analyse Data Set

# %%
# Power Generation Distribution


plt.figure.Figure(figsize=(6,6))
sns.distplot(data["kw_total"], hist=True);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48664 entries, 0 to 48721
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state_name                 48664 non-null  object
#  1   region_name                48664 non-null  int64
#  2   percent_qualified          48664 non-null  float64
#  3   yearly_sunlight_kwh_total  48664 non-null  float64
#  4   number_of_panels_total     48664 non-null  float64
#  5   lat_avg                    48664 non-null  float64
#  6   lng_avg                    48664 non-null  float64
#  7   kw_total                   48664 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 3.3+ MB

# %%
# Grab Column types
def grab_column_names(df):
    cat_cols = [col for col in df.columns if df[col].dtypes == "O"]

    num_but_cat = [col for col in df.columns if df[col].nunique() < 10 and
                   df[col].dtypes != "O"]

    cat_but_car = [col for col in df.columns if df[col].nunique() > 10 and
                   df[col].dtypes == "O"]

    cat_cols = cat_cols + num_but_cat

    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    # num_cols
    num_cols = [col for col in df.columns if df[col].dtypes != "O"]

    num_cols = [col for col in num_cols if col not in num_but_cat]

    print(f"Observations: {df.shape[0]}")
    print(f"Variables: {df.shape[1]}")
    print(f'cat_cols: {len(cat_cols)}')
    print(f'num_cols: {len(num_cols)}')
    print(f'cat_but_car: {len(cat_but_car)}')
    print(f'num_but_cat: {len(num_but_cat)}')

    return cat_cols, num_cols, cat_but_car

# %%
cat_cols, num_cols, cat_but_car = grab_column_names(data)
# Out:
# Observations: 48664
# Variables: 8
# cat_cols: 0
# num_cols: 7
# cat_but_car: 1
# num_but_cat: 0

# %%
X = data.iloc[:,:-1]
Y = data.iloc[:,-1]

# %%
#encode categorical Data
country_encoder = LabelEncoder()
country_encoder.fit(data['state_name'])
country_code = country_encoder.transform(data['state_name'])
type(country_code)
# Out:
# numpy.ndarray

# %%
data['Country_code']=country_code.tolist()
temp=data['kw_total']
data=data.drop(columns=['state_name','kw_total'],axis=1)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7600/3876260862.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Country_code']=country_code.tolist()

# %%
data['kw_total']=temp.tolist()
data
# Out:
#        region_name  percent_qualified  yearly_sunlight_kwh_total  \
# 0       6037104401          86.303387               7.922383e+06
# 1      36055009400          85.813953               3.117606e+07
# 2      17201000700          56.446991               8.337565e+06
# 3      42003180300          38.297872               3.912445e+06
# 4       6059086602          90.382514               2.241812e+07
# ...            ...                ...                        ...
# 48717  48121020113          84.426947               2.197206e+07
# 48718  34027042302          45.887850               2.146542e+07
# 48719   6037543322          96.548550               3.264987e+07
# 48720  45079010309          83.550045               3.321077e+07
# 48721  36079011300         100.000000               3.027023e+04
#
#        number_of_panels_total    lat_avg     lng_avg  Country_code  kw_total
# 0                     20876.0  34.267040 -118.432716             4   5219.00
# 1                    113565.0  43.156368  -77.607040            32  28391.25
# 2                     29409.0  42.277794  -89.066589            13   7352.25
# 3                     14393.0  40.422962  -79.993729            38   3598.25
# 4                     60394.0  33.844044 -117.933113             4  15098.50
# ...                       ...        ...         ...           ...       ...
# 48717                 64522.0  33.176277  -96.911400            43  16130.50
# 48718                 74373.0  40.838047  -74.476219            30  18593.25
# 48719                 86153.0  33.852547 -118.256958             4  21538.25
# 48720                104058.0  34.113491  -81.140663            40  26014.50
# 48721                   102.0  41.360306  -73.730499            32     25.50
#
# [48664 rows x 8 columns]

# %%
num_cols = [col for col in num_cols if col not in ["kw_total"]]

# %%
num_cols
# Out:
# ['region_name',
#  'percent_qualified',
#  'yearly_sunlight_kwh_total',
#  'number_of_panels_total',
#  'lat_avg',
#  'lng_avg']

# %%
#idenitify outlier thresholds
def outlier_thresholds(dataframe, col_name, q1=0.05, q3=0.95):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

# %%
#check outliers
def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
outlier_replaced=pd.DataFrame()
for col in num_cols:
    outliers = []
    print(col, check_outlier(data, col))
    
    outlier_status=check_outlier(data, col)
    median = np.median(data[col])
    if(outlier_status==True):
        low_limit, up_limit = outlier_thresholds(data, col)
        print("Low Limit\t:",low_limit)
        print("Up Limit\t:",up_limit)
        print("Original \t:",data[col].head())
        
        outlier_replaced[col] = np.where(((data[col]>up_limit)|(data[col]<low_limit)), median,data[col])
        print("Replaced Outliers \t:",outlier_replaced[col].head())
        print("======="*10)
    else:
        outlier_replaced[col]=data[col]
# Out:
# region_name False
# percent_qualified False
# yearly_sunlight_kwh_total True
# Low Limit	: -84134885.74762493
# Up Limit	: 146038947.06537488
# Original 	: 0    7.922383e+06
# 1    3.117606e+07
# 2    8.337565e+06
# 3    3.912445e+06
# 4    2.241812e+07
# Name: yearly_sunlight_kwh_total, dtype: float64
# Replaced Outliers 	: 0    7.922383e+06
# 1    3.117606e+07
# 2    8.337565e+06
# 3    3.912445e+06
# 4    2.241812e+07
# Name: yearly_sunlight_kwh_total, dtype: float64
# ======================================================================
# number_of_panels_total True
# Low Limit	: -251224.25000000003
# Up Limit	: 438360.55000000005
# Original 	: 0     20876.0
# 1    113565.0
# 2     29409.0
# 3     14393.0
# 4     60394.0
# Name: number_of_panels_total, dtype: float64
# Replaced Outliers 	: 0     20876.0
# 1    113565.0
# 2     29409.0
# 3     14393.0
# 4     60394.0
# Name: number_of_panels_total, dtype: float64
# ======================================================================
# lat_avg False
# lng_avg False

# %%
outlier_replaced
# Out:
#        region_name  percent_qualified  yearly_sunlight_kwh_total  \
# 0       6037104401          86.303387               7.922383e+06
# 1      36055009400          85.813953               3.117606e+07
# 2      17201000700          56.446991               8.337565e+06
# 3      42003180300          38.297872               3.912445e+06
# 4       6059086602          90.382514               2.241812e+07
# ...            ...                ...                        ...
# 48717  48121020113          84.426947               2.197206e+07
# 48718  34027042302          45.887850               2.146542e+07
# 48719   6037543322          96.548550               3.264987e+07
# 48720  45079010309          83.550045               3.321077e+07
# 48721  36079011300         100.000000               3.027023e+04
#
#        number_of_panels_total    lat_avg     lng_avg
# 0                     20876.0  34.267040 -118.432716
# 1                    113565.0  43.156368  -77.607040
# 2                     29409.0  42.277794  -89.066589
# 3                     14393.0  40.422962  -79.993729
# 4                     60394.0  33.844044 -117.933113
# ...                       ...        ...         ...
# 48717                 64522.0  33.176277  -96.911400
# 48718                 74373.0  40.838047  -74.476219
# 48719                 86153.0  33.852547 -118.256958
# 48720                104058.0  34.113491  -81.140663
# 48721                   102.0  41.360306  -73.730499
#
# [48664 rows x 6 columns]

# %%
from matplotlib import pyplot as plt1
def Box_plots(col):
    plt1.figure(figsize=(10,4))
    plt1.title("Box Plot")
    sns.boxplot(outlier_replaced[col])
    plt1.show()

# %%
type(outlier_replaced)
# Out:
# pandas.core.frame.DataFrame

# %%
data_pro = pd.DataFrame(outlier_replaced)

# %%
data_pro['Country_code']=data['Country_code']
data_pro['kw_total']=data['kw_total']

# %%
data_pro
# Out:
#        region_name  percent_qualified  yearly_sunlight_kwh_total  \
# 0       6037104401          86.303387               7.922383e+06
# 1      36055009400          85.813953               3.117606e+07
# 2      17201000700          56.446991               8.337565e+06
# 3      42003180300          38.297872               3.912445e+06
# 4       6059086602          90.382514               2.241812e+07
# ...            ...                ...                        ...
# 48717  48121020113          84.426947               2.197206e+07
# 48718  34027042302          45.887850               2.146542e+07
# 48719   6037543322          96.548550               3.264987e+07
# 48720  45079010309          83.550045               3.321077e+07
# 48721  36079011300         100.000000               3.027023e+04
#
#        number_of_panels_total    lat_avg     lng_avg  Country_code  kw_total
# 0                     20876.0  34.267040 -118.432716             4   5219.00
# 1                    113565.0  43.156368  -77.607040            32  28391.25
# 2                     29409.0  42.277794  -89.066589            13   7352.25
# 3                     14393.0  40.422962  -79.993729            38   3598.25
# 4                     60394.0  33.844044 -117.933113             4  15098.50
# ...                       ...        ...         ...           ...       ...
# 48717                 64522.0  33.176277  -96.911400            43  16130.50
# 48718                 74373.0  40.838047  -74.476219            30  18593.25
# 48719                 86153.0  33.852547 -118.256958             4  21538.25
# 48720                104058.0  34.113491  -81.140663            40  26014.50
# 48721                   102.0  41.360306  -73.730499            32     25.50
#
# [48664 rows x 8 columns]

# %%
# for col in num_cols:
#     print(Box_plots(col))

# %%
# Correlation Table

plt.figure.Figure(figsize=(100, 100))
sns.heatmap(outlier_replaced[num_cols].corr());

# %%
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# data_pro=sc.fit_transform(data_pro)

# %%
# data_pro=pd.DataFrame(data_pro)

# %%
data_pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48664 entries, 0 to 48721
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   region_name                48664 non-null  int64
#  1   percent_qualified          48664 non-null  float64
#  2   yearly_sunlight_kwh_total  48664 non-null  float64
#  3   number_of_panels_total     48664 non-null  float64
#  4   lat_avg                    48664 non-null  float64
#  5   lng_avg                    48664 non-null  float64
#  6   Country_code               48664 non-null  int64
#  7   kw_total                   48664 non-null  float64
# dtypes: float64(6), int64(2)
# memory usage: 3.3 MB

# %%
X = data_pro.iloc[:,:-1]
X
# Out:
#        region_name  percent_qualified  yearly_sunlight_kwh_total  \
# 0       6037104401          86.303387               7.922383e+06
# 1      36055009400          85.813953               3.117606e+07
# 2      17201000700          56.446991               8.337565e+06
# 3      42003180300          38.297872               3.912445e+06
# 4       6059086602          90.382514               2.241812e+07
# ...            ...                ...                        ...
# 48717  48121020113          84.426947               2.197206e+07
# 48718  34027042302          45.887850               2.146542e+07
# 48719   6037543322          96.548550               3.264987e+07
# 48720  45079010309          83.550045               3.321077e+07
# 48721  36079011300         100.000000               3.027023e+04
#
#        number_of_panels_total    lat_avg     lng_avg  Country_code
# 0                     20876.0  34.267040 -118.432716             4
# 1                    113565.0  43.156368  -77.607040            32
# 2                     29409.0  42.277794  -89.066589            13
# 3                     14393.0  40.422962  -79.993729            38
# 4                     60394.0  33.844044 -117.933113             4
# ...                       ...        ...         ...           ...
# 48717                 64522.0  33.176277  -96.911400            43
# 48718                 74373.0  40.838047  -74.476219            30
# 48719                 86153.0  33.852547 -118.256958             4
# 48720                104058.0  34.113491  -81.140663            40
# 48721                   102.0  41.360306  -73.730499            32
#
# [48664 rows x 7 columns]

# %%
Y = data_pro.iloc[:,-1]
Y
# Out:
# 0         5219.00
# 1        28391.25
# 2         7352.25
# 3         3598.25
# 4        15098.50
#            ...
# 48717    16130.50
# 48718    18593.25
# 48719    21538.25
# 48720    26014.50
# 48721       25.50
# Name: kw_total, Length: 48664, dtype: float64

# %%
X = data_pro.iloc[:,:-1]
Y = data.iloc[:,-1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 1)

# %%
Y
# Out:
# 0         5219.00
# 1        28391.25
# 2         7352.25
# 3         3598.25
# 4        15098.50
#            ...
# 48717    16130.50
# 48718    18593.25
# 48719    21538.25
# 48720    26014.50
# 48721       25.50
# Name: kw_total, Length: 48664, dtype: float64

# %%
pipelines = []
pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()),('LR',LinearRegression())])))
pipelines.append(('ScaledLASSO', Pipeline([('Scaler', StandardScaler()),('LASSO', Lasso())])))
pipelines.append(('ScaledEN', Pipeline([('Scaler', StandardScaler()),('EN', ElasticNet())])))
pipelines.append(('ScaledKNN', Pipeline([('Scaler', StandardScaler()),('KNN', KNeighborsRegressor())])))
pipelines.append(('ScaledCART', Pipeline([('Scaler', StandardScaler()),('CART', DecisionTreeRegressor())])))
pipelines.append(('ScaledGBM', Pipeline([('Scaler', StandardScaler()),('GBM', GradientBoostingRegressor())])))

results = []
names = []
for name, model in pipelines:
    kfold = KFold(n_splits=10, random_state=21, shuffle=True)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='neg_mean_squared_error')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# ScaledLR: -78048507.078781 (18785758.393639)
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.668e+11, tolerance: 9.550e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.937e+11, tolerance: 9.606e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.057e+10, tolerance: 9.569e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.365e+11, tolerance: 9.477e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.111e+11, tolerance: 9.586e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.074e+11, tolerance: 9.682e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.412e+11, tolerance: 9.639e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.548e+11, tolerance: 9.671e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.386e+11, tolerance: 9.582e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.401e+11, tolerance: 9.514e+08
#   model = cd_fast.enet_coordinate_descent(
# ScaledLASSO: -78055189.042419 (18791524.676051)
# ScaledEN: -86715173.386217 (17733598.257121)
# ScaledKNN: -68859805.797176 (17371170.129373)
# ScaledCART: -21159451.206583 (10526809.145930)
# ScaledGBM: -9464278.325458 (5302915.422110)

# %%
scaler = StandardScaler().fit(X_train)
rescaledX = scaler.transform(X_train)
param_grid = dict(n_estimators=np.array([50,75,80,90,100,150,200,300,400]))
model = GradientBoostingRegressor(random_state=21)
kfold = KFold(n_splits=10, random_state=21,shuffle=True)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_squared_error', cv=kfold)
grid_result = grid.fit(rescaledX, Y_train)

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# -9922674.166662 (5953293.901108) with: {'n_estimators': 50}
# -9442531.017438 (5444189.187197) with: {'n_estimators': 75}
# -9437021.876133 (5406101.147885) with: {'n_estimators': 80}
# -9470192.938815 (5337487.903077) with: {'n_estimators': 90}
# -9477658.486257 (5316605.382238) with: {'n_estimators': 100}
# -9707146.078448 (5433112.729780) with: {'n_estimators': 150}
# -9943262.707335 (5319632.035705) with: {'n_estimators': 200}
# -10390700.636460 (5605601.717663) with: {'n_estimators': 300}
# -10890660.074240 (5916235.187635) with: {'n_estimators': 400}
# Best: -9437021.876133 using {'n_estimators': 80}

# %%
scaler = StandardScaler().fit(X_train)
rescaled_X_train = scaler.transform(X_train)
model = GradientBoostingRegressor(random_state=21, n_estimators=80)
model.fit(rescaled_X_train, Y_train)

# transform the validation dataset
rescaled_X_test = scaler.transform(X_test)
predictions = model.predict(rescaled_X_test)
print (mean_squared_error(Y_test, predictions))
# Out:
# 11642137.872068863

# %%
compare = pd.DataFrame({'Prediction': predictions, 'Test Data' : Y_test})
compare.sort_index().head(10)
# Out:
#       Prediction  Test Data
# 2    7206.272728    7352.25
# 10  14235.232696   13543.50
# 12  15945.945584   15831.00
# 23  24511.645505   24783.25
# 25  14847.432086   14665.50
# 40  15801.857695   15759.50
# 44  12588.456252   12434.25
# 45  18984.399735   18918.00
# 58   2918.692830    2913.25
# 69  19130.380142   19143.25

# %%
#save Model File
pickle.dump(model, open("Regression_model_for_Power_Generation.pkl", "wb"))

# %%
#Load Model for predictio
loaded_model = pickle.load(open("Regression_model_for_Power_Generation.pkl", "rb"))

# %%
X_test.sort_index()
# Out:
#        region_name  percent_qualified  yearly_sunlight_kwh_total  \
# 2      17201000700          56.446991               8.337565e+06
# 10     28049002100          56.684492               1.742622e+07
# 12     48201451403          95.863309               2.005020e+07
# 23     27055020100          78.819158               2.794334e+07
# 25     33017081100          51.560284               1.690050e+07
# ...            ...                ...                        ...
# 48694  39049007951          98.742138               3.628122e+07
# 48700  36059519300          80.597015               5.895235e+07
# 48704   1097000903          81.203008               8.421377e+06
# 48709  48167725200          83.628922               8.430295e+06
# 48711   6099002702          95.457064               3.752236e+07
#
#        number_of_panels_total    lat_avg     lng_avg  Country_code
# 2                     29409.0  42.277794  -89.066589            13
# 10                    54174.0  32.315193  -90.224022            24
# 12                    63324.0  29.745672  -95.621521            43
# 23                    99133.0  43.820091  -91.297836            23
# 25                    58662.0  43.161507  -70.876389            29
# ...                       ...        ...         ...           ...
# 48694                126687.0  40.054760  -83.112473            35
# 48700                196072.0  40.765751  -73.513748            32
# 48704                 25570.0  30.677395  -88.073486             0
# 48709                 25338.0  29.290489  -94.821640            43
# 48711                103387.0  37.615566 -120.966522             4
#
# [9733 rows x 7 columns]

# %%
X_test.sort_index().iloc[[2]]
# Out:
#     region_name  percent_qualified  yearly_sunlight_kwh_total  \
# 12  48201451403          95.863309                20050200.32
#
#     number_of_panels_total    lat_avg    lng_avg  Country_code
# 12                 63324.0  29.745672 -95.621521            43

# %%
# Rescale test inputs
scaler = StandardScaler().fit(X_train)
rescaled_X_test_one = scaler.transform(X_test.sort_index().iloc[[2]])

# %%
Y_test[12]
# Out:
# 15831.0

# %%
#Predict Test inputs
Y_pred=loaded_model.predict(rescaled_X_test_one)

# %%
#Output Results - Power Generation for the year per particular location
Y_pred
# Out:
# array([15945.94558449])
